# %% [markdown]
# #Export all Tickets from Zendesk using the API and Python
# In this notebook, I’ll walk you through exporting tickets, users, and organizations from Zendesk using the API and Python for data analysis.

# %%
# Import the Zenpy Class
from zenpy import Zenpy
import requests
import pandas as pd
import json
import datetime as dt
from datetime import timezone
from datetime import datetime
import time
from pprint import pprint

# %%
# enter credentials
creds = {
    'email': 'epineda@myd4.com',
    'token': 'FntvSrwHVkbMHCK51hIRBjLXcZXK8EoLoJ6ST16p',
    'subdomain': 'myd4'
}

subdomain = 'myd4'
email = 'epineda@myd4.com'
token = 'FntvSrwHVkbMHCK51hIRBjLXcZXK8EoLoJ6ST16p'
# The documentation say that you have to inherit parameters, check it.
zenpy_client = Zenpy(subdomain=subdomain, email=email, token=token)

# %%
# TODO enter credentials
creds = {
    'email': 'epineda@myd4.com',
    'token': 'FntvSrwHVkbMHCK51hIRBjLXcZXK8EoLoJ6ST16p',
    'subdomain': 'myd4'
}

subdomain = 'myd4'
email = 'epineda@myd4.com'
token = 'FntvSrwHVkbMHCK51hIRBjLXcZXK8EoLoJ6ST16p'
zenpy_client = Zenpy(subdomain=subdomain, email=email, token=token)


def export_organizations():
    organizations = zenpy_client.organizations()
    org_data = []
    user_names = []
    cont_test = 1

    for organization in organizations:
        org_id = str(organization.id)
        users = zenpy_client.search(
            'type:user organization_id:{}'.format(org_id))

        for user in users:
            user_names.append(user.name)

            # print("User ID:", user.id)

        # print(user_info)
        # print(user_names)
        org_data.append({
            'ID': organization.id,
            'Name': organization.name,
            'Domain Names': organization.domain_names,
            'Tags': organization.tags,
            'Created At': organization.created_at,
            'Updated At': organization.updated_at,
            'Shared Tickets': organization.shared_tickets,
            'Shared Comments': organization.shared_comments,
            'Group ID': organization.group_id,
            'External ID': organization.external_id,
            'Details': organization.details,
            'Notes': organization.notes,
            # 'Users': user_names
            # Add more fields as needed
        })

        # user_info = ""
        if cont_test == 2:
            break
        cont_test += 1
    return org_data


# Call the export_organizations function to retrieve organization data
org_data = export_organizations()

# Print the exported organization data
for org in org_data:
    print(org)
# Out:
# {'ID': 370403949113, 'Name': '1928 Jewelry Company', 'Domain Names': [], 'Tags': [], 'Created At': '2020-05-22T19:34:14Z', 'Updated At': '2020-05-26T16:15:29Z', 'Shared Tickets': False, 'Shared Comments': False, 'Group ID': None, 'External ID': None, 'Details': '', 'Notes': '', 'Users': ['Faha Sharapov', 'ebay', '1928 Orders', 'postmaster', '1928 Paypal', 'Pia Assaratana', 'Mel Bernie', 'Violeta Villalta', 'Online Marketing', 'Rebecca Romero', 'Lisa Standen', 'Amie Davis', 'Remy Tolentino', 'Christina Cantu', 'Junior Sanchez', 'Maria Caballero', '1928 Print', 'Rene Guardado', '1928 Amazon', 'Virgie Dadian', 'Nancy Tranchi', 'Reports', 'Jonathan Rico', 'Carlos Becerra', 'Rebecca Marciano', 'Omar Guzman', 'Crystal Paminutan', 'Irina Krakov', 'Ipad Images', 'Hami Ghazarian', '1928 CustomerService', 'Domain', 'Abraham Ramirez', 'Gary Arian', 'Jerry Bernie', 'Magnolia Store', 'Kris Huether', 'Marketing', 'Kathy Cook', 'Maribel Pacheco', 'admin', 'Juliet Ohanian', 'Giovanni Sanchez', 'Abdu
# ...

# %%
# get organization id
subdomain = 'myd4'
email = 'epineda@myd4.com'
token = 'FntvSrwHVkbMHCK51hIRBjLXcZXK8EoLoJ6ST16p'
zenpy_client = Zenpy(subdomain=subdomain, email=email, token=token)

organizations = zenpy_client.organizations()

organization_ids = []
organization_names = []

for organization in organizations:
    organization_ids.append(organization.id)
    organization_names.append(organization.name)


print(len(organization_ids))
print(len(organization_names))
print(organization_ids[1])
print(organization_names[1])
# Out:
# 452
# 452
# 370403988833
# 1st State Home Heathcare Inc

# %%
# Extract information from a single organization 

subdomain = 'myd4'
email = 'epineda@myd4.com'
token = 'FntvSrwHVkbMHCK51hIRBjLXcZXK8EoLoJ6ST16p'
zenpy_client = Zenpy(subdomain=subdomain, email=email, token=token)

organizations = zenpy_client.organizations()

# Select a specific organization
organization_users = []

target_organization_id = "370403988833" # Replace with the desired organization ID
# Get users for the selected organization
users = zenpy_client.search('type:user organization_id:{}'.format(target_organization_id))
for user in users:
    organization_users.append({
        "User_ID":user.id,
        "User_Name":user.name,
        "User_Email":user.email,

    })
print(organization_users)
# Out:
# [{'User_ID': 411453582754, 'User_Name': 'Abdul Majeed', 'User_Email': 'a.majeed@sbcglobal.net'}]

# %%
# Get users for the selected organization
subdomain = 'myd4'
email = 'epineda@myd4.com'
token = 'FntvSrwHVkbMHCK51hIRBjLXcZXK8EoLoJ6ST16p'
zenpy_client = Zenpy(subdomain=subdomain, email=email, token=token)
cont = 0
# organization_ids = ["370403949113", "370403988833", "370403987193", "370381732274"]
# organization_names = ["test1", "test2", "test3", "test 4"]


def retrieve_organization_users():
    organization_users = []

    for organization_id, organization_name in zip(organization_ids, organization_names):
        cont = 0
        # Get users for the selected organization
        users = zenpy_client.search(
            'type:user organization_id:{}'.format(organization_id))

        for user in users:
            if cont == 1:
                break

            organization_users.append({
                "Organization_ID": organization_id,
                "Organization_Name": organization_name,
                "User_ID": user.id,
                "User_Name": user.name,
                "User_Email": user.email
            })
            cont+=1

    return organization_users


def save_organization_users_to_csv(organization_users):
    organization_users_df = pd.DataFrame(organization_users)
    file_name = "organization_users_testing.csv"
    organization_users_df.to_csv(file_name, index=False)


# Retrieve organization users
organization_users = retrieve_organization_users()

# Save organization users to CSV
save_organization_users_to_csv(organization_users)
# Out:
# Waiting for requested retry-after period: 1 seconds

# %%
# Get customer data 
def export_customers():
    customers = zenpy_client.users(role='end-user')
    customer_data = []
    # cont_test=1
    for customer in customers:
        customer_data.append({
            'ID': customer.id,
            'Name': customer.name,
            'Email': customer.email,
            'Organization ID': customer.organization_id,
            'Created At': customer.created_at,
            'Updated At': customer.updated_at,
            'Role': customer.role,
            'Phone': customer.phone,
            'Locale': customer.locale,
            'Last Login At': customer.last_login_at,
            'Verified': customer.verified,
            # Add more fields as needed
        })
        # if cont_test == 4:
        #     break
        # cont_test += 1

    return customer_data


# Call the export_customers function to retrieve customer data
customer_data = export_customers()

# Print the exported customer data
for customer in customer_data:
    print(customer)
# Out:
# {'ID': 409915952993, 'Name': 'Josue Maldonado', 'Email': 'jmaldonado@myd4.com', 'Organization ID': 370417943294, 'Created At': '2020-05-07T03:57:43Z', 'Updated At': '2023-05-25T19:09:51Z', 'Role': 'end-user', 'Phone': None, 'Locale': 'en-US', 'Last Login At': '2023-05-25T19:09:51Z', 'Verified': True}
# {'ID': 409953940713, 'Name': 'josuemaldonado', 'Email': 'josuemaldonado@outlook.com', 'Organization ID': None, 'Created At': '2020-05-07T15:59:35Z', 'Updated At': '2020-05-08T00:12:35Z', 'Role': 'end-user', 'Phone': None, 'Locale': 'en-US', 'Last Login At': '2020-05-08T00:12:35Z', 'Verified': True}
# {'ID': 409982051933, 'Name': 'Josue Maldonado', 'Email': 'j@josuemaldonado.com', 'Organization ID': None, 'Created At': '2020-05-07T20:41:15Z', 'Updated At': '2020-05-22T17:22:05Z', 'Role': 'end-user', 'Phone': None, 'Locale': 'en-US', 'Last Login At': None, 'Verified': False}
# ...

# %%
customer_df = pd.DataFrame(customer_data)
customer_df.to_csv('customer zendesk data.csv', index=False)

# %%
filtered_rows = customer_df[customer_df['Organization ID'].isnull()]
customer_notOrganization = pd.DataFrame(filtered_rows)
customer_notOrganization.to_csv(
    'customer with Not OrganizationID.csv', index=False)

# %%
# Define the desired ticket statuses
ticket_statuses = ['new', 'open', 'pending', 'hold', 'solved', 'closed']

tickets = []

# Retrieve tickets for each status
for status in ticket_statuses:
    status_tickets = zenpy_client.search(type='ticket', status=status)
    tickets.extend(status_tickets)

df_tickets = pd.DataFrame(columns=['id', 'requester_id', 'submitter_id',
                                   'created_at', 'subject', 'description',
                                   'tags', 'channel', 'status', 'organization_id', 'priority', 'type'])

# Extract ticket information
for ticket in tickets:
    row = {
        'id': ticket.id,
        'requester_id': ticket.requester_id,
        'submitter_id': ticket.submitter_id,
        'created_at': ticket.created_at,
        'subject': ticket.subject,
        'description': ticket.description,
        'tags': ticket.tags,
        'channel': ticket.via.channel,
        'status': ticket.status,
        'organization_id': ticket.organization_id,
        'priority': ticket.priority,
        'type': ticket.type,
    }

    df_tickets = df_tickets.append(row, ignore_index=True)

# Export DataFrame to CSV
df_tickets.to_csv('tickets.csv', index=False)

# %%
# Export ticket information
# ticket_statuses = ['new', 'open', 'pending', 'hold', 'solved', 'closed']
open_tickets = zenpy_client.search(type='ticket', status='open')
audit_tickets=[]

tickets = []

for ticket in open_tickets:
    tickets.append(ticket.to_dict())
tickets[0]

df_tickets = pd.DataFrame(columns=['id', 'requester_id', 'submitter_id', 
                                   'created_at', 'subject', 'description', 
                                   'tags', 'channel', 'status',"organization_id","priority","type"])
for ticket in tickets:
    audit_tickets.append(ticket['id'])
    row = {
        'id': ticket['id'],
        'requester_id': ticket['requester_id'],
        'submitter_id': ticket['submitter_id'],
        'created_at': ticket['created_at'],
        'subject': ticket['subject'],
        'description': ticket['description'],        
        'tags': ticket['tags'],
        'channel': ticket['via']['channel'],
        'organization_id': ticket['organization_id'],
        'priority': ticket['priority'],
        'type': ticket['type'],
    }
    
    df_tickets = df_tickets.append(row, ignore_index=True) 
df_tickets.to_csv('open_tickets.csv', index=False)
df_tickets.head(1)

# %%
df_tickets.to_csv('open_tickets.csv', index=False)
df_tickets.head(3)

# %%
import requests
import pandas as pd
from pandas.io.json import json_normalize
import time

creds = {
    'email': 'epineda@myd4.com',
    'token': 'FntvSrwHVkbMHCK51hIRBjLXcZXK8EoLoJ6ST16p',
    'subdomain': 'myd4'
}

subdomain = 'myd4'
username = 'epineda@myd4.com'
token = 'FntvSrwHVkbMHCK51hIRBjLXcZXK8EoLoJ6ST16p'


def get_ticket(ticket_id):
    url = f'https://{subdomain}.zendesk.com/api/v2/tickets/{ticket_id}/audits'
    auth = (f'{username}/token', token)
    response = requests.get(url, auth=auth)
    if response.status_code == 200:
        return response.json()
    else:
        return None

audit_data = []  # List to store the audit information

for items in audit_tickets:
    ticket = get_ticket(items)
    if ticket:
        audits = ticket["audits"]
        audit_data.extend(audits)  # Add audits to the audit_data list
    else:
        print('Ticket not found or an error occurred.')

# Save the audit_data as a JSON file
with open('audit_data.json', 'w') as jsonfile:
    json.dump(audit_data, jsonfile)

# %%
import requests
import datetime
from pprint import pprint

subdomain = 'myd4'
username = 'epineda@myd4.com'
token = 'FntvSrwHVkbMHCK51hIRBjLXcZXK8EoLoJ6ST16p'
ticket_for_testing = []
# Set up the API endpoint and headers
endpoint = f'https://{subdomain}.zendesk.com/api/v2/incremental/ticket_events.json'
auth = (f'{username}/token', token)

# Define the start time as 7 days after May 29th
start_time_str = '2023-04-29 00:00:00'
start_time = datetime.datetime.strptime(start_time_str, '%Y-%m-%d %H:%M:%S')
start_time += datetime.timedelta(days=7)

# Convert the start time to a Unix epoch time (in seconds)
start_time_unix = int(start_time.timestamp())
# print(start_time_unix)

params = {
    'start_time': start_time_unix
}

response = requests.get(endpoint, auth=auth, params=params)

# Check the response status code
if response.status_code == 200:
    # The request was successful
    data = response.json()
    events_list = []

    # Process the data and add events to the list
    for event in data['ticket_events']:
        pprint(event["ticket_id"])
        ticket_for_testing.append(event["ticket_id"])
        # pprint(event)

        # event_id = event['id']
        # event_body = event['body']
        # events_list.append({
        #     'Event ID': event_id,
        #     'Event Body': event_body
        # })

    # Print the events list
    # for event in events_list:
    #     pprint(event["ticket_id"])
else:
    # There was an error in the request
    print('Error:', response.status_code, response.text)
# Out:
# 29834
# 29866
# 29823
# 29866
# 29842
# 29867
# 29867
# 29818
# 29813
# 29817
# 29773
# 29694
# 29867
# 29700
# 29790
# 29822
# 29868
# 29791
# 29868
# 29826
# 29832
# 29333
# 29801
# 29868
# 29869
# 29869
# 29852
# 29833
# 29849
# 29551
# 29869
# 29864
# 29824
# 29848
# 29848
# 29830
# 29831
# 29854
# 29827
# 29828
# 29806
# 29789
# 29852
# 29805
# 29793
# 29523
# 29836
# 29870
# 29871
# 29872
# 29873
# 29872
# 29870
# 29871
# 29873
# 29874
# 29875
# 29870
# 29874
# 29875
# 29871
# 29876
# 29877
# 29871
# 29871
# 29870
# 29870
# 29878
# 29879
# 29870
# 29878
# 29876
# 29879
# 29871
# 29877
# 29880
# 29881
# 29882
# 29883
# 29880
# 29876
# 29881
# 29883
# 29877
# 29876
# 29882
# 29877
# 29877
# 29884
# 29885
# 29886
# 29887
# 29838
# 29882
# 29882
# 29888
# 29889
# 29882
# 29886
# 29888
# 29884
# 29885
# 29887
# 29889
# 29877
# 29890
# 29891
# 29884
# 29884
# 29849
# 29551
# 29891
# 29890
# 29891
# 29890
# 29891
# 29877
# 29884
# 29890
# 29877
# 29884
# 29884
# 29498
# 29842
# 29849
# ...

# %%
len(ticket_for_testing)
# Out:
# 1000

# %%
ticket_for_testing
import requests
import pandas as pd
from pandas.io.json import json_normalize
import time

creds = {
    'email': 'epineda@myd4.com',
    'token': 'FntvSrwHVkbMHCK51hIRBjLXcZXK8EoLoJ6ST16p',
    'subdomain': 'myd4'
}

subdomain = 'myd4'
username = 'epineda@myd4.com'
token = 'FntvSrwHVkbMHCK51hIRBjLXcZXK8EoLoJ6ST16p'

testing_ticket =["29834","29866","29823","29866","29842"]
def get_ticket(ticket_id):
    url = f'https://{subdomain}.zendesk.com/api/v2/tickets/{ticket_id}/audits'
    auth = (f'{username}/token', token)
    response = requests.get(url, auth=auth)
    if response.status_code == 200:
        return response.json()
    else:
        return None

audit_data = []  # List to store the audit information

for items in testing_ticket:
    ticket = get_ticket(items)
    if ticket:
        audits = ticket["audits"]
        pprint(audits, sort_dicts=False)
        audit_data.extend(audits)  # Add audits to the audit_data list
    else:
        print('Ticket not found or an error occurred.')

# # Save the audit_data as a JSON file
# with open('audit_data.json', 'w') as jsonfile:
#     json.dump(audit_data, jsonfile)
# Out:
# [{'id': 14334124969623,
#   'ticket_id': 29834,
#   'created_at': '2023-05-03T16:42:07Z',
#   'author_id': 1534687652461,
#   'metadata': {'system': {'message_id': '<0qTvR000000000000000000000000000000000000000000000RU3D1V00kM3l5Nd9TGyCUfCAdV0y8Q@sfdc.net>',
#                           'email_id': '01GZH7W49K743BBM13EAD0PE47',
#                           'ip_address': '10.182.204.131',
#                           'raw_email_identifier': '9914657/ac1d38d1-ec79-4177-88a9-b1c25628fa01.eml',
#                           'json_email_identifier': '9914657/ac1d38d1-ec79-4177-88a9-b1c25628fa01.json',
#                           'eml_redacted': False},
#                'custom': {},
#                'suspension_type_id': None,
#                'notifications_suppressed_for': [410010847874]},
#   'events': [{'id': 14334124969751,
#               'type': 'Comment',
#               'author_id': 1534687652461,
#               'body': 'Hello Team ,\n'
# ...

# %%
import requests
import datetime
from pprint import pprint
import html2text

subdomain = 'myd4'
username = 'epineda@myd4.com'
token = 'FntvSrwHVkbMHCK51hIRBjLXcZXK8EoLoJ6ST16p'

# Set up the API endpoint and headers

auth = (f'{username}/token', token)


# Function to get ticket audits
def get_ticket(ticket_id):
    url = f'https://{subdomain}.zendesk.com/api/v2/tickets/{ticket_id}/audits'
    response = requests.get(url, auth=auth)
    if response.status_code == 200:
        return response.json()
    else:
        return None

audit_data = []  # List to store the audit information
testing_ticket =["29834","29866","29823","29866","29842"]
for ticket_id in testing_ticket:
    ticket = get_ticket(ticket_id)
    if ticket:
        audits = ticket["audits"]
        for audit in audits:
            events = audit["events"]
            for event in events:
                if event.get("body"):
                    # Convert HTML to plain text
                    body_text = html2text.html2text(event["body"])
                    html_body = html2text.html2text(event["html_body"])
                    plain_body = html2text.html2text(event["plain_body"])
                    event["body"] = body_text.strip()  # Replace HTML body with plain text
                    event["html_body"] = body_text.strip()  
                    event["plain_body"] = body_text.strip()  
        audit_data.extend(audits)  # Add audits to the audit_data list
    else:
        print('Ticket not found or an error occurred.')

# Print the formatted audit data
pprint(audit_data, sort_dicts=False)

# %%
# Remember that you are catching the wrong csv file look for a form to get one prev key 
import requests
import datetime
from pprint import pprint
import html2text
subdomain = 'myd4'
username = 'epineda@myd4.com'
token = 'FntvSrwHVkbMHCK51hIRBjLXcZXK8EoLoJ6ST16p'
# Set up the API endpoint and headers
auth = (f'{username}/token', token)
# Function to get ticket audits
def get_ticket(ticket_id):
    url = f'https://{subdomain}.zendesk.com/api/v2/tickets/{ticket_id}/audits'
    response = requests.get(url, auth=auth)
    if response.status_code == 200:
        return response.json()
    else:
        return None

audit_data = []  # List to store the audit information
testing_ticket = ["29834", "29866", "29823", "29866", "29842"]

for ticket_id in testing_ticket:
    ticket = get_ticket(ticket_id)
    if ticket:
        # pprint(ticket)
        print(ticket["audits"][0]['author_id'])
        audits = ticket["audits"]
        for audit in audits:
            events = audit["events"]
            for event in events:
                body_text = html2text.html2text(event.get("body", ""))
                event["body"] = body_text.strip()  # Replace HTML body with plain text

                html_body_text = html2text.html2text(event.get("html_body", ""))
                event["html_body"] = html_body_text.strip()

                plain_body_text = html2text.html2text(event.get("plain_body", ""))
                event["plain_body"] = plain_body_text.strip()

        audit_data.extend(audits)  # Add audits to the audit_data list
    else:
        print('Ticket not found or an error occurred.')

# Print the formatted audit data
for audit in audit_data:
    pprint(audit)
    print("Audit ID:", audit["id"])
    print("author_id:", audit["author_id"])
    print("Ticket ID:", audit["ticket_id"])
    print("Created At:", audit["created_at"])
    print("Events:")
    for event in audit["events"]:
        print("\tEvent ID:", event["id"])
        print("\tEvent Type:", event["type"])
        print("\tEvent Body:", event["body"])
        print("\tEvent HTML Body:", event["html_body"])
        print("\tEvent Plain Body:", event["plain_body"])
        print("-------------------------------------")
    pass
    # print("=====================================")
# Out:
# 1534687652461
# 14407138129687
# 1534321796142
# 14407138129687
# 1509294057741
# {'author_id': 1534687652461,
#  'created_at': '2023-05-03T16:42:07Z',
#  'events': [{'attachments': [],
#              'audit_id': 14334124969623,
#              'author_id': 1534687652461,
#              'body': 'Hello Team , Greetings of the Day ! Here is the summary '
#                      'of the call that we\n'
#                      'had , \\- Found the vCenter patches were failing due to '
#                      '/storage/log and\n'
#                      '/storage/core partition being full . \\- Followed this '
#                      'KB for deleting the log\n'
#                      'partition '
#                      '-https://kb.vmware.com/s/article/83070?lang=en_US \\- '
#                      'Also for\n'
#                      'clearing the /storage/core partition , followed this\n'
#                      '-https://kb.vmware.com/s/article/81327?lang=en_US \\- '
# ...

# %%
len(audit_data)
# Out:
# 82

# %%
import pandas as pd
import requests
import datetime
from pprint import pprint
import html2text

subdomain = 'myd4'
username = 'epineda@myd4.com'
token = 'FntvSrwHVkbMHCK51hIRBjLXcZXK8EoLoJ6ST16p'

# Set up the API endpoint and headers
auth = (f'{username}/token', token)

# Function to get ticket audits
def get_ticket(ticket_id):
    url = f'https://{subdomain}.zendesk.com/api/v2/tickets/{ticket_id}/audits'
    response = requests.get(url, auth=auth)
    if response.status_code == 200:
        return response.json()
    else:
        return None

audit_data = []  # List to store the audit information
author_id = []  # List to store the audit information
testing_ticket = ["29834", "29866", "29823", "29866", "29842"]

for ticket_id in testing_ticket:
    ticket = get_ticket(ticket_id)
    if ticket:
        # pprint(ticket)
        unique_author_id = ticket["audits"][0]['author_id']
        audits = ticket["audits"]
        for audit in audits:
            events = audit["events"]
            for event in events:
                body_text = html2text.html2text(event.get("body", ""))
                event["body"] = body_text.strip()  # Replace HTML body with plain text

                html_body_text = html2text.html2text(event.get("html_body", ""))
                event["html_body"] = html_body_text.strip()

                plain_body_text = html2text.html2text(event.get("plain_body", ""))
                event["plain_body"] = plain_body_text.strip()

                event_combined = " | ".join(filter(None, [body_text, html_body_text, plain_body_text]))
                event["combined_body"] = event_combined

        audit_data.extend(audits)  # Add audits to the audit_data list
    else:
        print('Ticket not found or an error occurred.')

# Create a pandas DataFrame from the audit data
data = []

for audit,author in zip(audit_data,author_id):
    # pass
    # pprint(audit)
    audit_id = audit["id"]
    audit_author_id = author
    print(audit_author_id)
    audit_id = audit["author_id"]
    ticket_id = audit["ticket_id"]
    created_at = audit["created_at"]
    events = audit["events"]
    for event in events:
        event_id = event["id"]
        event_type = event["type"]
        event_combined_body = event.get("combined_body", "")
        
        data.append([audit_id, ticket_id, created_at, event_id, event_type, event_combined_body])

columns = ['Audit ID', 'Ticket ID', 'Created At', 'Event ID', 'Event Type', 'Combined Body']
df = pd.DataFrame(data, columns=columns)

# Print the DataFrame
print(df)

df.to_csv(f"testing.csv", index=False)
# Out:
# Empty DataFrame
# Columns: [Audit ID, Ticket ID, Created At, Event ID, Event Type, Combined Body]
# Index: []

# %%
import pandas as pd
import requests
import datetime
from pprint import pprint
import html2text
import csv
from datetime import datetime
subdomain = 'myd4'
username = 'epineda@myd4.com'
token = 'FntvSrwHVkbMHCK51hIRBjLXcZXK8EoLoJ6ST16p'

# Set up the API endpoint and headers
auth = (f'{username}/token', token)

audit_data = []  # List to store the audit information
author_id = []  # List to store the author IDs
testing_ticket = ["29834", "29866", "29823", "29866", "29842"]


# Function to get ticket audits
def get_ticket(ticket_id):
    url = f'https://{subdomain}.zendesk.com/api/v2/tickets/{ticket_id}/audits'
    response = requests.get(url, auth=auth)
    if response.status_code == 200:
        return response.json()
    else:
        return None


for ticket_id in testing_ticket:
    print(ticket_id)
    ticket = get_ticket(ticket_id)
    if ticket:
        
        unique_author_id = ticket["audits"][0]['author_id']
        author_id.append(unique_author_id)
        audits = ticket["audits"]
        for audit in audits:
            events = audit["events"]
            for event in events:
                body_text = html2text.html2text(event.get("body", ""))
                event["body"] = body_text.strip()  # Replace HTML body with plain text

                html_body_text = html2text.html2text(event.get("html_body", ""))
                event["html_body"] = html_body_text.strip()

                plain_body_text = html2text.html2text(event.get("plain_body", ""))
                event["plain_body"] = plain_body_text.strip()

                event_combined = " | ".join(filter(None, [body_text, html_body_text, plain_body_text]))
                event["combined_body"] = event_combined

        audit_data.extend(audits)  # Add audits to the audit_data list
    else:
        print('Ticket not found or an error occurred.')

rows = []

for ticket_id, audit, author in zip(testing_ticket, audit_data, author_id):
    row = []
    row.append(str(ticket_id))
    row.append(str(author))

    # Format the created_at date
    created_at = datetime.strptime(audit["created_at"], "%Y-%m-%dT%H:%M:%SZ")
    formatted_created_at = created_at.strftime("%m/%d/%Y %I:%M %p")
    row.append(formatted_created_at)

    events = audit["events"]
    combined_bodies = ', '.join([event.get("combined_body", "") for event in events])

    row.append(combined_bodies)

    rows.append(row)

columns = ['Ticket ID', 'Author ID', 'Created At', 'Combined Bodies']

# Create a pandas DataFrame from the rows
df = pd.DataFrame(rows, columns=columns)

# Write the DataFrame to an Excel file
filename = 'testing.xlsx'
df.to_excel(filename, index=False)

# print(f"Excel file '{filename}' created successfully.")
# Out:
# 29834
# 29866
# 29823
# 29866
# 29842

# %% [markdown]
# Here you will change the form to get zendesk data you already have company and customer data you have to get properly information about the tickets
#
# [✔] Get information of a single ticket
# [✔] Audit tickets and format the information without html syntax
# [✔] create a structure for the ticket
#     Ticket_ID , Title, company, (Status), date, Autor_ID
# [✔] Itarate for a list of tickets

# %%
import pandas as pd
import requests
import json
import datetime
from pprint import pprint
import html2text
import csv
from datetime import datetime

# %%
import requests

subdomain = 'myd4'
username = 'epineda@myd4.com'
token = 'FntvSrwHVkbMHCK51hIRBjLXcZXK8EoLoJ6ST16p'

# Set up the API endpoint and headers
endpoint = f'https://{subdomain}.zendesk.com/api/v2/tickets.json'
auth = (f'{username}/token', token)

# List to store ticket IDs
ticket_ids = []

# Define the per_page parameter to control the number of tickets per page
per_page = 100

# Pagination loop
next_page = endpoint
while next_page:
    response = requests.get(next_page, auth=auth, params={'per_page': per_page})

    # Check the response status code
    if response.status_code == 200:
        data = response.json()
        # pprint(data)
        tickets = data['tickets']

        # Extract ticket IDs and add them to the list
        for ticket in tickets:
            ticket_ids.append(ticket['id'])

        # Check if there are more pages
        next_page = data['next_page']
    else:
        # There was an error in the request
        print('Error:', response.status_code, response.text)
        break

# Print the ticket IDs
# for ticket_id in ticket_ids:
#     print(ticket_id)

len(ticket_ids)
# Out:
# 1532

# %%
# Get information from a single ticket

# credentials 
subdomain = 'myd4'
username = 'epineda@myd4.com'
token = 'FntvSrwHVkbMHCK51hIRBjLXcZXK8EoLoJ6ST16p'

# Set up the API endpoint and headers
auth = (f'{username}/token', token)

audit_data = []  # List to store the audit information
author_id = []  # List to store the author IDs
ticket_id = 29823


def get_ticket(ticket_id):
    url = f'https://{subdomain}.zendesk.com/api/v2/tickets/{ticket_id}'
    response = requests.get(url, auth=auth)
    if response.status_code == 200:
        return response.json()
    else:
        return None
    
ticket = get_ticket(ticket_id)
if ticket:
    # pprint(ticket , sort_dicts=False)
    print("Ticket Information:")
    print("ID:", ticket['ticket']["id"])
    print("Subject:", ticket['ticket']["subject"])
    print("Status:", ticket['ticket']["status"])
    print("created_at:", ticket['ticket']["created_at"])
    print("organization_id:", ticket['ticket']["organization_id"])
    print("address:", ticket['ticket']['via']['source']['from']['address'])
    print("address:", ticket['ticket']['via']['source']['from']['name'])
    # Add more fields as needed
else:
    print("Failed to retrieve ticket information.")
# Out:
# Ticket Information:
# ID: 29823
# Subject: FW: CBSSD-174 MS Project License Has Expired
# Status: closed
# created_at: 2023-05-02T15:15:16Z
# organization_id: 4831538242327
# address: sbailey@chainbridgesolutions.com
# address: Stephen Bailey

# %%
import pandas as pd
import requests
from datetime import datetime

# credentials
subdomain = 'myd4'
username = 'epineda@myd4.com'
token = 'FntvSrwHVkbMHCK51hIRBjLXcZXK8EoLoJ6ST16p'

# Set up the API endpoint and headers
auth = (f'{username}/token', token)


# ticket_ids = ["28826","28829"]  # List of ticket IDs to retrieve information for

data = []  # List to store ticket information

for ticket_id in ticket_ids[1100:]:
    def get_ticket(ticket_id):
        url = f'https://{subdomain}.zendesk.com/api/v2/tickets/{ticket_id}'
        response = requests.get(url, auth=auth)
        if response.status_code == 200:
            return response.json()
        else:
            return None

    ticket = get_ticket(ticket_id)
    # print(ticket)
    if ticket:
        # pprint(ticket ,sort_dicts=False)
        created_at = datetime.strptime(ticket['ticket']["created_at"], "%Y-%m-%dT%H:%M:%SZ")
        formatted_created_at = created_at.strftime("%m/%d/%Y %I:%M %p")
        # pprint(ticket)
        # ticket_info = {
        #     "ID": ticket['ticket']["id"],
        #     "Subject": ticket['ticket']["subject"],
        #     "Status": ticket['ticket']["status"],
        #     "Created At": formatted_created_at,
        #     "Organization ID": ticket['ticket']["organization_id"],
        #     "Address": ticket['ticket']['via']['source']['from']['address'],
        #     "Name": ticket['ticket']['via']['source']['from']['name']
        # }
        ticket_id = ticket['ticket'].get('id')
        subject = ticket['ticket'].get('subject')
        status = ticket['ticket'].get('status')
        created_at = ticket['ticket'].get('created_at')
        org_id = ticket['ticket'].get('organization_id')

        # Check for the existence of nested keys
        source = ticket['ticket']['via']['source']
        if 'from' in source and source['from']:
            if 'address' in source['from']:
                address = source['from']['address']
            else:
                address = ""
            if 'name' in source['from']:
                name = source['from']['name']
            else:
                name = ""
        else:
            address = ""
            name = ""

            # Create the ticket info dictionary
        ticket_info = {
            "ID": ticket_id,
            "Subject": subject,
            "Status": status,
            "Created At": formatted_created_at,
            "Organization ID": org_id,
            "Address": address,
            "Name": name
        }
        data.append(ticket_info)
    else:
        print("Failed to retrieve ticket information for Ticket ID", ticket_id)


# Create a DataFrame from the collected data
ticket_information_df = pd.DataFrame(data)
# print(df)

# %%
ticket_information_df
# Out:
#         ID                                            Subject  Status  \
# 0    29976  D4 Analyzer: MCM-LEX-4331-01 | 172.22.40.222 |...  closed
# 1    29977  D4 Analyzer: MCM-LEX-9200-Stack-01.cpa.local |...  closed
# 2    29978  D4 Analyzer: MCM-LEX-9200-Stack-01.cpa.local |...  closed
# 3    29979  D4 Analyzer: MCM-LEX-4331-01 | 172.22.40.222 |...  closed
# 4    29980  D4 Analyzer: MCM-LEX-9200-Stack-01.cpa.local |...  closed
# ..     ...                                                ...     ...
# 427  30483  Re: Twiching USA & Canada Dialer Termination P...    open
# 428  30484  TKRG - Edward James Courtyard (EJC)-(Bouchon B...  solved
# 429  30485  Microsoft 365 security: You have messages in q...  solved
# 430  30486  Microsoft 365 security: You have messages in q...  solved
# 431  30487                  Additional Office 365 F3 Licenses    open
#
#               Created At  Organization ID                             Address  \
# ...

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# Function to get ticket audits
def get_ticket_audit(ticket_id):
    url = f'https://{subdomain}.zendesk.com/api/v2/tickets/{ticket_id}/audits'
    response = requests.get(url, auth=auth)
    if response.status_code == 200:
        return response.json()
    else:
        return None


ticket_descriptions = []
# testing_ticket = ["29834","29866","29823","29866"]

for ticket_id in ticket_ids[1100:]:
    ticket = get_ticket_audit(ticket_id)
    if ticket:
        audits = ticket["audits"]
        ticket_description = ''  # Initialize ticket description for each ticket
        for audit in audits:
            events = audit["events"]
            for event in events:
                body_text = event.get("body", "")
                testing1 = BeautifulSoup(body_text, "html.parser").get_text().strip()

                if testing1:
                    ticket_description += testing1 + '\n\n'  # Append ticket description
        ticket_descriptions.append(ticket_description)

# Create a DataFrame with each ticket's information in a separate cell
audit_information_df = pd.DataFrame(ticket_descriptions, columns=["Ticket Description"])
# Out:
# c:\Users\mlopezg\Anaconda3\lib\site-packages\bs4\__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(

# %%
ticket_structure_df = pd.concat([ticket_information_df, audit_information_df], axis=1)

# %%
ticket_structure_df.to_excel("Data information.xlsx" ,index=False)

# %%
# Autotask testing

# import requests

# # Set up your Autotask credentials and API endpoint
# username = 'your_username'
# username_key = 'your_api_key'  # Replace with your Autotask API key
# api_url = 'https://ww24.api.autotask.net'

# # Create a session and set the authentication credentials
# session = requests.Session()
# session.headers.update({
#     'Content-Type': 'application/json',
#     'ApiIntegrationVendor': 'YourVendorName',
#     'ApiIntegrationProduct': 'YourProductName',
#     'User-Agent': 'Python Autotask API'
# })
# session.auth = (username, username_key)

# # Specify the user ID to delete
# user_id = '12345'  # Replace with the ID of the user you want to delete

# # Make the delete request to delete the user
# response = session.delete(f'{api_url}/users/{user_id}')

# # Check if the request was successful
# if response.status_code == 200:
#     print(f"User with ID {user_id} deleted successfully.")
# else:
#     print(f"Failed to delete user with ID {user_id}.")
