# %%
from requests.exceptions import HTTPError
import requests
from requests.auth import HTTPBasicAuth
import base64
import json
import datetime as dt
import pandas as pd
import warnings
import time
import regex as re
import smtplib
import csv
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
from email.mime.application import MIMEApplication
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
warnings.filterwarnings("ignore")

# %%
# List tenants for connections

tenants = ['12th-gate-napa-valley', '1967-cellars-napa-valley', '1883-reserve-napa-valley',
       '510-pearl-napa-valley', '90-broad-napa-valley',
       'black-and-gold-napa-valley', 'bold-stripes-napa-valley',
       'brownstown-napa-valley', 'ever-blooming-napa-valley',
       'excelsior-napa-valley', 'green-19-napa-valley', 'fairwinds-estate-winery',
       'first-moon-napa-valley', 'foolish-club-napa-valley',
       'founders-rock-napa-valley', 'four-points-napa-valley',
       'golden-anchor-napa-valley', 'great-day-napa-valley',
       'great-minds-napa-valley', 'horns-tail-napa-valley',
       'in-hoc-napa-valley', 'killarney-napa-valley',
       'landfall-napa-valley', 'les-soeurs-fideles-napa-valley','long-gray-line-napa-valley','maverick-moon-napa-valley',
       'mountain-born-napa-valley', 'mystic-circle-napa-valley',
       'nineteen-seventeen-napa-valley', 'obbligato-napa-valley',
       'one-heart-napa-valley', 'parasol-napa-valley', 'perpetual-napa-valley',
       'phiphika-napa-valley', 'prowling-vineyards-napa-valley',
       'radiant-napa-valley', 'rattlesnake-napa-valley',
       'red-door-napa-valley', 'ruby-points-napa-valley',
       'seeing-eye-napa-valley', 'spindletop-napa-valley',
       'steel-curtain-napa-valley', 'tg-napa-valley', 'the-fleur-napa-valley',
       'the-ivy-napa-valley', 'three-degrees-napa-valley',
       'three-strings-napa-valley', 'tower-napa-valley',
       'true-north-napa-valley', 'unmatched-napa-valley',
       'vine-04-napa-valley', 'winning-drive-napa-valley']

# %%
tenants = ['steel-curtain-napa-valley']

# %%
# Instantiate empty array

products = []
testing_name = []

# Loop over tenants and assign tenantcode and brand
  
tenant_info = {
    'fairwinds-estate-winery': ('FEW', 'Fairwinds Estate Winery'),
    '12th-gate-napa-valley': ('12G', '12th Gate'),
    '510-pearl-napa-valley': ('5P', '510 Pearl'),
    '90-broad-napa-valley': ('90B', '90 Broad'),
    'black-and-gold-napa-valley': ('BG', 'Black & Gold'),
    'brownstown-napa-valley': ('BT', 'Brownstown'),
    'excelsior-napa-valley': ('EX', 'Excelsior'),
    'first-moon-napa-valley': ('FM', 'First Moon'),
    'foolish-club-napa-valley': ('FOO', 'Foolish Club'),
    'founders-rock-napa-valley': ('FR', 'Founders Rock'),
    'four-points-napa-valley': ('FP', 'Four Points'),
    'golden-anchor-napa-valley': ('GA', 'Golden Anchor'),
    'great-day-napa-valley': ('GD', 'Great Day'),
    'in-hoc-napa-valley': ('IH', 'In Hoc'),
    'killarney-napa-valley': ('KI', 'Killarney'),
    'maverick-moon-napa-valley': ('MM', 'Maverick Moon'),
    'mountain-born-napa-valley': ('MB', 'Mountain Born'),
    'mystic-circle-napa-valley': ('MC', 'Mystic Circle'),
    'nineteen-seventeen-napa-valley': ('NS', 'Nineteen Seventeen'),
    'one-heart-napa-valley': ('OH', 'One Heart'),
    'parasol-napa-valley': ('PR', 'Parasol'),
    'phiphika-napa-valley': ('PHI', 'PhiPhiKa'),
    'prowling-vineyards-napa-valley': ('PV', 'Prowling Vineyards'),
    'radiant-napa-valley': ('RA', 'Radiant'),
    'rattlesnake-napa-valley': ('RS', 'Rattlesnake'),
    'red-door-napa-valley': ('RD', 'Red Door'),
    'rituelle-napa-valley': ('RT', 'Rituelle'),
    'ruby-points-napa-valley': ('RP', 'Ruby Points'),
    'seeing-eye-napa-valley': ('SE', 'Seeing Eye'),
    'spindletop-napa-valley': ('ST', 'Spindletop'),
    'tg-napa-valley': ('TG', 'TG'),
    'the-ivy-napa-valley': ('IV', 'The Ivy'),
    'three-degrees-napa-valley': ('TD', 'Three Degrees'),
    'three-strings-napa-valley': ('TS', 'Three Strings'),
    'tower-napa-valley': ('TW', 'Tower'),
    'true-north-napa-valley': ('TN', 'True North'),
    'unmatched-napa-valley': ('UN', 'Unmatched'),
    'winning-drive-napa-valley': ('WD', 'Winning Drive'),
    'landfall-napa-valley': ('LF', 'Landfall'),
    'obbligato-napa-valley': ('OB', 'Obbligato'),
    'ever-blooming-napa-valley': ('EB', 'Ever Blooming'),
    'great-minds-napa-valley': ('GM', 'Great Minds'),
    'steel-curtain-napa-valley': ('SC', 'Steel Curtain'),
    '1967-cellars-napa-valley': ('CL', '1967 Cellars'),
    'horns-tail-napa-valley': ('HT', 'Horns & Tail'),
    'vine-04-napa-valley': ('V4', 'Vine 04'),
    'bold-stripes-napa-valley': ('BS', 'Bold Stripes'),
    'perpetual-napa-valley': ('PER', 'Perpetual'),
    'green-19-napa-valley': ('WS', 'Winning Standard'),
    '1883-reserve-napa-valley': ('YS', 'Yellowstone'),
    'long-gray-line-napa-valley': ('LG', 'Long Gray Line'),
    'les-soeurs-fideles-napa-valley': ('LS', 'Les Soeurs Fideles'),
    'the-fleur-napa-valley': ('TF', 'The Fleur')
}

for t in tenants: 
    tenantcode, brand = tenant_info.get(t, ('NaN', 'NaN'))
    # print(f"{t}: {tenantcode}, {brand}")
    # testing_name.append(t)
    # Instantiate cursor

    params = {'cursor': 'start'}

    while True:
        url = 'https://api.commerce7.com/v1/product?updatedAt=gte:2023-06-14'
        response = requests.get(url, auth = HTTPBasicAuth('wilfredo@fewinery.com', 'Conexion@4$'), 
                                headers = {"tenant":t, "Content-Type":"application/json"},
                                params=params)

        res = response.json()
        #logging.info(res)
    
        formater = json.dumps(response.json(),indent=4, sort_keys=True )
        print(formater)

        #upDate = str(datetime.datetime.today())
        for row in res['products']:
            row['tenant'] = t
            row['tenantCode'] = tenantcode
            row['brand'] = brand
            #row['uniqueOrderNumber'] = tenantcode + str(row['orderNumber'])
            #row['updateDate'] = upDate
            #row['orderYear'] = parser.parse(row['orderSubmittedDate']).strftime("%Y")
            #row.pop('giftMessage')
            #promotions = row.get('promotions')
            #row['promotionTitles'] = None if promotions == None else " - ".join(k['title'] for k in promotions)
            #row['promDiscount'] = None if promotions == None else sum(k['totalValue'] for k in promotions)
            #coupons = row.get('coupons')
            #row['couponTitles'] = None if coupons == None else " - ".join(k['title'] for k in coupons)
            #row['couponDiscount'] = None if coupons == None else sum(k['totalValue'] for k in coupons)
            #row['transType'] = 'Deposit' if (len(row['items']) == 1 and row['total'] == 5000) else row['purchaseType']
            #shipping = row.get('shipping')
            #row['carrierName'] = None if shipping == None else ' - '.join(k.get('carrier') for k in shipping) 
            #row['shippingMethod'] = None if shipping == None else ' - '.join(k.get('service') for k in shipping)
            products.append(row)
            testing_name.append(t)
            
        if (cursor := res.get('cursor')):
            params['cursor'] = cursor
            #print(len(res['orders']), tenantorders[-1]['orderNumber'], tenantorders[-1]['tenantCode'])
        else:
            #print(len(res['orders']), tenantorders[-1]['orderNumber'], tenantorders[-1]['tenantCode'])
            break
        
    print(response, t, len(products))
    # print(tenants_name)
# Out:
# {
#     "products": [
#         {
#             "adminStatus": "Available",
#             "appData": null,
#             "appSync": null,
#             "bundleItems": [
#                 {
#                     "id": "5225beff-de0b-44f7-9472-13697eb88934",
#                     "image": "https://images.commerce7.com/images/noimages/original/no-image.png",
#                     "price": 1995,
#                     "productId": "07530397-bf5d-4748-b571-f61f6a3d4f74",
#                     "productTitle": "3D Holiday Card",
#                     "productVariantId": "afb1270c-e3eb-455e-88d2-1bb767363230",
#                     "productVariantTitle": "Each",
#                     "quantity": 1,
#                     "sku": "NW-12G3DHC"
#                 },
#                 {
#                     "id": "5ff8207e-c210-4ea7-a544-6814a3a73ff4",
#                     "image": "https://images.commerce7.com/12th-gate-napa-valley/images/original/12thgate_screwdriverkeychain-1677530027682.png",
# ...

# %%
print(len(testing_name))
# Out:
# 42

# %%
#Creacion completa

lista1 = []
lista2 = []
incorrect_tenantdf= [] 
correct_tenantdf= [] 
incorrect_sku=[]
errors=[]
result=""



for row in products:
    number = products.index(row)
    try:
        # number = products.index(row)
        my_token = "eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCIsImtpZCI6IlJUQXlOVU13T0Rrd09ETXhSVVZDUXpBNU5rSkVOVVUxUmtNeU1URTRNMEkzTWpnd05ERkdNdyJ9.eyJodHRwOi8vc2hpcGhlcm8tcHVibGljLWFwaS91c2VyaW5mbyI6eyJuYW1lIjoid3Jvc2FsZXNAb3NpbmVhcnNob3JlLmNvbSIsIm5pY2tuYW1lIjoid3Jvc2FsZXMiLCJwaWN0dXJlIjoiaHR0cHM6Ly9zLmdyYXZhdGFyLmNvbS9hdmF0YXIvYmUwNTY0ZTk0OGQ5NTgxOTE2Zjg1MTRmMmM5MzU1MjI_....M0yWTtBYdPRZbonjd9oSHKuWX5ylJ9hGbrdi307Q-97ut4onrO4AksEe8GUrsD6AgWrXo2cRiDzqA-pDLhUo-HGxl9wc8NogMBjPA8YNAWg2qCVgyjxbPJ5umtsucG0534_00wMtUOjAWp10ifUBVRSHLO23-mc32xkYxvl3CrYcfb4NPo6YBPDKCNLufR9U3Es90kWlUKrx6TEmU0U65-Hz-nWdF96rQE2O3OeGWdmSnVPgr_0gPCroVaALSvUOozuqiJQT4eq52lfRLXtjj02inN7nxLApSIfx6hJH5Vk-hwrYqh_BgcnaylAI3PfKT7BdjWYucdp3oNo8Gn3KUA"
        _transport = RequestsHTTPTransport( url='https://public-api.shiphero.com/graphql', use_json=True, )
        _transport.headers = { "User-Agent": "Mozilla/5.0 (X11; buntu; " + "Linux x86_64; rv:58.0) Gecko/0100101 Firefox/58.0", "Authorization": "Bearer {}".format(my_token), "content-type": "application/json", }
        client = Client( transport=_transport, fetch_schema_from_transport=True, )

        # print("paso1")

        #The IDs of the warehouses where the product will be created
        warehouse_id1 = "V2FyZWhvdXNlOjgwODU0"
        warehouse_id2 = "V2FyZWhvdXNlOjgwNzE5"
        warehouse_id3 = "V2FyZWhvdXNlOjgwMzA2"

        #loads the product from the json file genereated in another script
        product = row
        product_variants = product['variants'][0]
        # print(product_variants)

        #query string to send to SH
        query = gql("""
mutation ($data: CreateProductInput!){
  product_create(data: $data) {
    request_id
    complexity
    product {
      id
      legacy_id
      account_id
      name
      sku
      barcode
      country_of_manufacture
      dimensions {
        weight
        height
        width
        length
      }
      created_at
    }
  }
}
        """)

        #defining all variables that will be sent with the gql query
        WarehouseProduct = [{
            'warehouse_id': warehouse_id1,
            'on_hand': 0
            },
        {
            'warehouse_id': warehouse_id2,
            'on_hand': 0
        },
        {
            'warehouse_id': warehouse_id3,
            'on_hand': 0
        }
        ]
        Dimensions = {
            'weight': str(product_variants['weight']),
            'height': "",
            'width': "",
            'length': ""
        }
        images = [
            {
              'src': str(product['image'])
            }
        ]

        if product_variants['sku'] == 'NW-WDWKFF':## Para arreglar el sku NW-WDWKFF
            product_variants['sku'] = 'NW-WDWK'
        elif product_variants['sku'] == 'TNWINEKEYF':
            product_variants['sku'] = 'NW-TNWK'
        elif re.search(r'^NW', product_variants['sku']) and re.search('WK', product_variants['sku']) and product_variants['sku'][-1] =='F':
            product_variants['sku'] = re.sub(r"F$", "", product_variants['sku']) #re.sub(r'F', "", sku)

        # print(product_variants['sku'])
        # product_variants['sku']="PC-LSSP23WB" #this have to break the program 

        CreateProductInput = {
        'name': product['subTitle'],
        'sku': product_variants['sku'],
        'warehouse_products': WarehouseProduct,
        'price': str(float(product_variants['price']/100)),
        'value': str(float(product_variants['costOfGood'])),
        'dimensions': Dimensions,
        'tags': ['Shopify Category Wine'],
        'images': images,
        }

        variables = {"data": CreateProductInput}


        try:
            result = client.execute(query, variable_values=variables)
            # result_string = json.dumps(result, indent=2)
            # print(result_string)
        except Exception as e:
            errors.append(str(e))
            raise ValueError("An error occurred.") 

        lista1.append(product_variants['sku']) #, result_string, result_string2)
        correct_tenantdf.append(testing_name[number])
        time.sleep(0.5)

        items = product['bundleItems']
        if len(items) > 0:
            for item in items:
                del item['id'], item['productId'], item['productVariantId'], item['productTitle'], item['productVariantTitle'], item['image'], item['price']
                if item['sku'] == 'NW-WDWKFF':## Para arreglar el sku NW-WDWKFF
                    item['sku'] = 'NW-WDWK'
                elif item['sku'] == 'TNWINEKEYF':
                    item['sku'] = 'NW-TNWK'
                elif re.search(r'^NW', item['sku']) and re.search('WK', item['sku']) and item['sku'][-1] =='F':
                    item['sku'] = re.sub(r"F$", "", item['sku']) #re.sub(r'F', "", sku)

        #query to add the bundle items to the product
            second_query = gql("""
            mutation kit_build($data: BuildKitInput!) {
    kit_build(data: $data) {
      request_id
      complexity
      product {
        sku
      }
    }
  }""")

            #variables of the second query
            BuildKitComponentInput = items

            BuildKitInput = {
                "sku": product_variants['sku'],
                "components": BuildKitComponentInput,
                "kit_build": False,
            }

            
            variables = {"data": BuildKitInput}

            result = client.execute(second_query, variable_values=variables)
            result_string2 = json.dumps(result, indent=2)
            print(result_string2)

            lista2.append(product_variants['sku']) #, result_string, result_string2)

            time.sleep(0.5)
            

    except:
        # print("capturo el incorrecto")
        incorrect_sku.append(product_variants['sku']) 
        incorrect_tenantdf.append(testing_name[number])

# %% [markdown]
# Fix tenant name bug
# fix index length bug in errors
# add orders in the csv file

# %%
incorrect_columns = ['Incorrect_SKU', ]
correct_columns = ['correct_SKU']

incorrect_df = pd.DataFrame(columns=incorrect_columns)
correct_df = pd.DataFrame(columns=correct_columns)

# incorrect_df["Incorrect_SKU"] = incorrect_sku
# incorrect_df["Tenant"] = incorrect_tenantdf

correct_df["correct_SKU"] = lista1
correct_df["Tenant"] = correct_tenantdf
incorrect_df["error"] = errors

incorrect_df.to_csv("incorrect_df.csv", index=False)
correct_df.to_csv("correct_df.csv", index=False)

# incorrect_df
# correct_df

# %%
# Define sender and recipient email addresses
# sender = 'marlon@fewinery.com'
# recipient = ['mlopezg@osinearshore.com', 'marlon@fewinery.com']

# # Define email message
# msg = MIMEMultipart()
# msg['Subject'] = 'sku test file'
# msg['From'] = sender
# msg['To'] = ', '.join(recipient)

# #  message to email body
# body = 'attached file with Incorrect SKU  information.'
# msg.attach(MIMEText(body, 'plain'))

# # Attach CSV file to email message
# with open('incorrect_df.csv', 'rb') as f:
#     part = MIMEApplication(f.read(), Name='incorrect_df.csv')
#     part['Content-Disposition'] = f'attachment; filename="incorrect_df.csv"'
#     msg.attach(part)

# # Attach second CSV file to email message
# with open('correct_df.csv', 'rb') as f2:
#     part2 = MIMEApplication(f2.read(), Name='correct_df.csv')
#     part2['Content-Disposition'] = f'attachment; filename="correct_df.csv"'
#     msg.attach(part2)

# # Send email
# with smtplib.SMTP('smtp.office365.com', 587) as server:
#     server.starttls()
#     server.login(sender, 'Bag97417')
#     server.sendmail(sender, recipient, msg.as_string())

# %%
import pandas as pd
import smtplib
from email.mime.multipart import MIMEMultipart
from email.mime.application import MIMEApplication
from email.mime.text import MIMEText

# Define the dataframes
         
incorrect_columns = ['Incorrect_SKU', ]
correct_columns = ['correct_SKU']

incorrect_df = pd.DataFrame(columns=incorrect_columns)
correct_df = pd.DataFrame(columns=correct_columns)

incorrect_df["Incorrect_SKU"] = incorrect_sku
incorrect_df["Tenant"] = incorrect_tenantdf

correct_df["correct_SKU"] = lista1
correct_df["Tenant"] = correct_tenantdf
incorrect_df["error"] = errors

# Create CSV strings from the dataframes
incorrect_csv = incorrect_df.to_csv(index=False)
correct_csv = correct_df.to_csv(index=False)

# Define email message
sender = 'marlon@fewinery.com'
recipient = ['mlopezg@osinearshore.com', 'marlon@fewinery.com']
msg = MIMEMultipart()
msg['Subject'] = 'SKU Test File'
msg['From'] = sender
msg['To'] = ', '.join(recipient)

# Add message body
body = 'Attached files contain information about incorrect and correct SKUs.'
msg.attach(MIMEText(body, 'plain'))

# Add the CSV files as attachments to the email message
part1 = MIMEApplication(incorrect_csv, Name='incorrect_df.csv')
part1['Content-Disposition'] = 'attachment; filename="incorrect_df.csv"'
msg.attach(part1)

part2 = MIMEApplication(correct_csv, Name='correct_df.csv')
part2['Content-Disposition'] = 'attachment; filename="correct_df.csv"'
msg.attach(part2)

# Send email
smtp=smtplib.SMTP('smtp.office365.com', 587)
smtp.starttls()
smtp.login(sender, 'Bag97417')
smtp.sendmail(sender, recipient, msg.as_string())
smtp.quit()
# Out:
# (221, b'2.0.0 Service closing transmission channel')
