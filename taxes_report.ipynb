# %%
import pandas as pd

# %%
taxes = pd.read_excel('./resources/January2023-City-Rates.xlsx')
taxes["testing"] = ""
taxes
# Out:
#      Use the up, down, left, and right arrows to navigate the worksheet  \
# 0     This one worksheet provides the tax rates for ...
# 1                                            All Cities
# 2                             Effective January 1, 2023
# 3     Please Note:  Some communities located within ...
# 4     * Indicates incorporated city or incorporated ...
# ...                                                 ...
# 1788                                           Yucaipa*
# 1789                                      Yucca Valley*
# 1790                                             Zamora
# 1791                                              Zenia
# 1792                                   End of Worksheet
#
#      Unnamed: 1      Unnamed: 2 testing
# 0           NaN             NaN
# 1           NaN             NaN
# 2           NaN             NaN
# 3           NaN             NaN
# 4           NaN             NaN
# ...         ...             ...     ...
# ...

# %%
# Add columns with a specific index
taxes.insert(2,"Info","")

# %%
# taxes = taxes.rename(columns={'column_0': 'column_1'})
taxes = taxes.rename(columns={1: 'new_name'})
taxes
# Out:
#                                                column_1 column_1 Info  \
# 0     This one worksheet provides the tax rates for ...      NaN
# 1                                            All Cities      NaN
# 2                             Effective January 1, 2023      NaN
# 3     Please Note:  Some communities located within ...      NaN
# 4     * Indicates incorporated city or incorporated ...      NaN
# ...                                                 ...      ...  ...
# 1788                                           Yucaipa*   0.0775
# 1789                                      Yucca Valley*   0.0875
# 1790                                             Zamora   0.0725
# 1791                                              Zenia   0.0725
# 1792                                   End of Worksheet      NaN
#
#           Unnamed: 2 testing
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ...              ...     ...
# ...
